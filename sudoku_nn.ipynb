# %%
import os
import glob
import ipdb
import random
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from sudoku import start as ORIGINAL_START, reward_goal, is_complete, is_valid, get_possible_actions, get_sudoku_grid
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
def _grid_to_onehot(grid):
    """Return (9,9,10) one-hot with channel 0 = empty, 1..9 values."""
    oh = np.zeros((9, 9, 10), dtype=np.float32)
    for r in range(9):
        for c in range(9):
            v = int(grid[r, c])
            oh[r, c, v] = 1.0
    return oh

def _q_snapshot_to_target(Qsnap):
    """
    Qsnap expected shape >= (9,9,10). Return (9,9,9) with channels for values 1..9.
    """
    return Qsnap[:9, :9, 1:10].astype(np.float32)

def load_snapshots_to_dataset(snapshots_dir='snapshots',
                              max_files=None,
                              max_examples=None,
                              flatten_input=True,
                              normalize_targets=True):
    """
    Read .npz snapshot files saved by the trainer and build MLP-ready X, Y arrays.
    - X: inputs shape (N, 810) if flatten_input else (N,9,9,10)
    - Y: targets shape (N, 729) flattened (9*9*9)
    Looks for files like snapshots/*.npz and also dataset_*.npz created earlier.
    """
    files = sorted(glob.glob(os.path.join(snapshots_dir, '*.npz')))
    if max_files:
        files = files[:max_files]

    X_list = []
    Y_list = []
    total = 0

    for f in files:
        try:
            data = np.load(f, allow_pickle=True)
        except Exception:
            continue

        # prefer pre-built dataset files
        if 'X' in data and 'Y' in data:
            X_block = data['X']  # expected (N,9,9) int grids
            Y_block = data['Y']  # expected (N,9,9,9) Q targets
            for i in range(len(X_block)):
                grid = X_block[i]
                qtarget = Y_block[i]
                oh = _grid_to_onehot(grid)
                if flatten_input:
                    X_list.append(oh.reshape(-1))
                else:
                    X_list.append(oh)
                Y_list.append(qtarget.reshape(-1))
                total += 1
                if max_examples and total >= max_examples:
                    break
            if max_examples and total >= max_examples:
                break
            continue

        # fallback: per-episode snapshot with 'states' and 'Q'
        if 'states' in data and 'Q' in data:
            states = data['states']   # (T,9,9)
            Qsnap = data['Q']         # full Q snapshot
            for i in range(len(states)):
                grid = states[i]
                qtarget = _q_snapshot_to_target(Qsnap)
                oh = _grid_to_onehot(grid)
                if flatten_input:
                    X_list.append(oh.reshape(-1))
                else:
                    X_list.append(oh)
                Y_list.append(qtarget.reshape(-1))
                total += 1
                if max_examples and total >= max_examples:
                    break
            if max_examples and total >= max_examples:
                break

    if len(X_list) == 0:
        return None, None

    X = np.stack(X_list).astype(np.float32)
    Y = np.stack(Y_list).astype(np.float32)

    if normalize_targets:
        # scale targets to roughly [-1,1] by dividing by reward_goal (non-zero)
        scale = float(max(1.0, abs(reward_goal)))
        Y = Y / scale

    return X, Y

def build_mlp(input_dim=810, output_dim=729, hidden_sizes=(1024, 512), lr=1e-3, dropout=0.2):
    """
    Build a simple feed-forward network using TensorFlow Keras.
    Returns compiled model.
    """
    inputs = tf.keras.Input(shape=(input_dim,), name='sudoku_input')
    x = inputs
    for i, h in enumerate(hidden_sizes):
        x = tf.keras.layers.Dense(h, activation='swish', name=f'dense_{i}')(x)
        if dropout and dropout > 0.0:
            x = tf.keras.layers.Dropout(dropout, name=f'dropout_{i}')(x)
    outputs = tf.keras.layers.Dense(output_dim, activation='linear', name='q_values')(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(lr),
                  loss='mse',
                  metrics=['mae'])
    return model

def train_mlp_from_snapshots(model_save='sudoku_mlp.keras',
                             snapshots_dir="snapshots/strategy2",
                             batch_size=128,
                             epochs=20,
                             val_split=0.1,
                             max_files=None,
                             max_examples=None):
    """
    Load dataset from snapshots, train MLP, save model to file.
    """
    model = build_mlp()
    cb = [
        tf.keras.callbacks.ModelCheckpoint(model_save, save_best_only=True, monitor='val_loss', verbose=1),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, cooldown=2, verbose=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
    ]
    for epoch in range(epochs):
        print("-----------------------------------")
        print(f"Epoch: {epoch}")
        print("-----------------------------------")
        for entry in os.listdir(snapshots_dir):
            snapshot = os.path.join(snapshots_dir, entry)
            print(f"Processing: {snapshot}")
            X, Y = load_snapshots_to_dataset(snapshot, max_files=max_files, max_examples=max_examples)
            if X is None:
                raise RuntimeError("No training data found in snapshots directory")
            
            history = model.fit(X, Y,
                                batch_size=batch_size,
                                epochs=1,
                                validation_split=val_split,
                                callbacks=cb,
                                verbose=2)
    model.save(model_save)
    return model, history

# %%
def predict_best_action_from_model(model, grid, legal_only=True, return_q=False):
    """
    Given a trained model and a grid (9x9), return best action (r,c,v).
    If legal_only=True restricts choices to get_possible_actions(grid).
    """
    oh = _grid_to_onehot(grid).reshape(1, -1).astype(np.float32)
    preds = model.predict(oh, verbose=0)[0]  # flattened 729
    # unnormalize if training used normalization
    preds = preds * float(max(1.0, abs(reward_goal)))

    # reshape to (9,9,9)
    qvals = preds.reshape(9, 9, 9)  # channels value=1..9 -> index 0..8

    best = None
    best_val = -float('inf')
    possible = get_possible_actions(grid) if legal_only else [(r, c, v) for r in range(9) for c in range(9) for v in range(1,10)]

    for (r, c, v) in possible:
        val = qvals[r, c, v-1]
        if val > best_val:
            best_val = val
            best = (r, c, v)

    if return_q:
        return best, best_val
    return best

def plot_sudoku_grid(grid, givens=None, filename=None, figsize=6):
    """
    Render a single 9x9 Sudoku grid using matplotlib.
    - grid: 9x9 ndarray of ints (0 = empty)
    - givens: optional 9x9 ndarray marking original clues (non-zero) to render in bold
              if None and ORIGINAL_START is available, that will be used.
    - filename: if provided the image is saved to this path, otherwise returns the Figure.
    Returns: matplotlib.Figure if filename is None, else the filename string.
    """
    grid = np.asarray(grid, dtype=int)
    assert grid.shape == (9, 9), "grid must be shape (9,9)"

    if givens is not None:
        givens = np.asarray(givens) != 0
    else:
        givens = np.zeros((9, 9), dtype=bool)

    fig, ax = plt.subplots(figsize=(figsize, figsize))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)
    ax.set_aspect('equal')

    # draw cell backgrounds and numbers
    count = 0
    for r in range(9):
        for c in range(9):
            val = int(grid[r, c])
            face = '#f2f2f2' if givens[r, c] else 'white'
            ax.add_patch(plt.Rectangle((c, r), 1, 1, facecolor=face, edgecolor='none'))
            if val != 0:
                color = 'black' if givens[r, c] else '#1f77b4'
                weight = 'bold' if givens[r, c] else 'normal'
                ax.text(c + 0.5, r + 0.5, str(val), ha='center', va='center',
                        fontsize=18, color=color, fontweight=weight)
            else:
                count += 1
    print(f"Accuracy: {((81-count)/81) * 100}")

    # grid lines: thick every 3 cells
    for i in range(10):
        lw = 2.5 if i % 3 == 0 else 0.8
        ax.plot([0, 9], [i, i], color='k', linewidth=lw)
        ax.plot([i, i], [0, 9], color='k', linewidth=lw)

    ax.invert_yaxis()
    ax.set_xticks([])
    ax.set_yticks([])
    plt.tight_layout()

    if filename:
        plt.savefig(filename, dpi=200)
        plt.close(fig)
        return filename
    return fig

    
def fill_grid_greedy_with_model(model, initial_grid, max_steps=200):
    """
    Greedily apply model's best legal action until complete or stuck.
    Returns list of grids (states).
    """
    grid = initial_grid.copy().astype(int)
    path = [grid.copy()]
    for _ in range(max_steps):
        if is_complete(grid):
            break
        action = predict_best_action_from_model(model, grid, legal_only=True)
        if action is None:
            break
        r, c, v = action
        grid[r, c] = v
        # if invalid (shouldn't happen if we used legal_only) break
        if not is_valid(grid):
            grid[r, c] = 0
            break
        path.append(grid.copy())
    return path
    
def load_model_and_solve(model_path,
                         grid,
                         save_image='sudoku_solution_nn.png',
                         return_path=False):
    """
    Load a saved keras model, run greedy inference to fill the sudoku,
    save the final grid image (if save_image provided) and return the path list.
    - initial_grid: 9x9 ndarray. If None and ORIGINAL_START is available it will be used.
    - return_path: if True return the sequence of grids, otherwise return None.
    """
    model = tf.keras.models.load_model(model_path)
    path = fill_grid_greedy_with_model(model, grid, max_steps=200)

    final_grid = path[-1]
    plot_sudoku_grid(final_grid, givens=grid, filename=save_image)

    if return_path:
        return path
    return None

# %%
model, history = train_mlp_from_snapshots(model_save='sudoku_mlp_2_layers_swish.keras', snapshots_dir="snapshots/strategy2")
# Out:
# -----------------------------------
# Epoch: 0
# -----------------------------------
# Processing: snapshots/strategy2/5
#
# Epoch 1: val_loss improved from None to 0.00000, saving model to sudoku_mlp_2_layers_swish.keras
# 3578/3578 - 17s - 5ms/step - loss: 4.6278e-05 - mae: 0.0033 - val_loss: 4.3442e-06 - val_mae: 0.0010 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/3
#
# Epoch 1: val_loss improved from 0.00000 to 0.00000, saving model to sudoku_mlp_2_layers_swish.keras
# 3539/3539 - 16s - 5ms/step - loss: 3.2401e-04 - mae: 0.0064 - val_loss: 4.1126e-06 - val_mae: 7.5274e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/2
#
# Epoch 1: val_loss did not improve from 0.00000
# 3325/3325 - 15s - 5ms/step - loss: 1.1259e-05 - mae: 0.0014 - val_loss: 7.1795e-06 - val_mae: 9.3280e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/4
#
# Epoch 1: val_loss did not improve from 0.00000
# 3456/3456 - 15s - 4ms/step - loss: 1.3238e-05 - mae: 0.0013 - val_loss: 1.4123e-05 - val_mae: 0.0012 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/1
#
# Epoch 1: val_loss did not improve from 0.00000
# 3317/3317 - 15s - 4ms/step - loss: 8.4186e-06 - mae: 0.0011 - val_loss: 7.1973e-06 - val_mae: 9.8926e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/8
#
# Epoch 1: val_loss improved from 0.00000 to 0.00000, saving model to sudoku_mlp_2_layers_swish.keras
# 3506/3506 - 16s - 4ms/step - loss: 7.3946e-06 - mae: 0.0010 - val_loss: 2.8106e-06 - val_mae: 4.7722e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/7
#
# Epoch 1: val_loss did not improve from 0.00000
# 3508/3508 - 16s - 4ms/step - loss: 7.9649e-06 - mae: 0.0010 - val_loss: 3.9720e-06 - val_mae: 6.6250e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/14
#
# Epoch 1: val_loss did not improve from 0.00000
# 3538/3538 - 16s - 4ms/step - loss: 1.2159e-05 - mae: 0.0013 - val_loss: 7.6553e-06 - val_mae: 0.0011 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/17
#
# Epoch 1: val_loss did not improve from 0.00000
# 3487/3487 - 16s - 4ms/step - loss: 5.6234e-06 - mae: 9.1773e-04 - val_loss: 2.9964e-06 - val_mae: 5.9827e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/12
#
# Epoch 1: val_loss did not improve from 0.00000
# 3393/3393 - 15s - 4ms/step - loss: 1.2457e-05 - mae: 0.0013 - val_loss: 1.0032e-05 - val_mae: 0.0011 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/11
#
# Epoch 1: val_loss did not improve from 0.00000
# 3504/3504 - 16s - 4ms/step - loss: 1.5257e-05 - mae: 0.0014 - val_loss: 5.6435e-06 - val_mae: 7.4155e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/10
#
# Epoch 1: val_loss did not improve from 0.00000
# 3446/3446 - 15s - 4ms/step - loss: 9.7132e-06 - mae: 0.0011 - val_loss: 3.9832e-06 - val_mae: 5.2547e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/15
#
# Epoch 1: val_loss improved from 0.00000 to 0.00000, saving model to sudoku_mlp_2_layers_swish.keras
# 3564/3564 - 16s - 4ms/step - loss: 9.4604e-06 - mae: 0.0012 - val_loss: 2.1015e-06 - val_mae: 4.8055e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/6
#
# Epoch 1: val_loss did not improve from 0.00000
# 3432/3432 - 15s - 4ms/step - loss: 7.5382e-06 - mae: 0.0011 - val_loss: 3.9402e-06 - val_mae: 6.6160e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/9
#
# Epoch 1: val_loss did not improve from 0.00000
# 3425/3425 - 15s - 4ms/step - loss: 5.0505e-06 - mae: 8.8160e-04 - val_loss: 5.1588e-05 - val_mae: 0.0025 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/16
#
# Epoch 1: val_loss did not improve from 0.00000
# 3416/3416 - 15s - 5ms/step - loss: 9.7040e-06 - mae: 0.0012 - val_loss: 6.7604e-06 - val_mae: 9.0373e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/20
#
# Epoch 1: val_loss did not improve from 0.00000
# 3503/3503 - 16s - 4ms/step - loss: 6.4486e-06 - mae: 0.0010 - val_loss: 6.0371e-06 - val_mae: 8.5558e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/19
#
# Epoch 1: val_loss did not improve from 0.00000
# 5774/5774 - 26s - 4ms/step - loss: 1.4577e-04 - mae: 0.0031 - val_loss: 6.3684e-05 - val_mae: 0.0021 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/18
#
# Epoch 1: val_loss did not improve from 0.00000
# 3409/3409 - 15s - 4ms/step - loss: 1.0927e-05 - mae: 0.0012 - val_loss: 3.5369e-06 - val_mae: 6.5358e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/13
#
# Epoch 1: val_loss improved from 0.00000 to 0.00000, saving model to sudoku_mlp_2_layers_swish.keras
# 3292/3292 - 15s - 5ms/step - loss: 4.1977e-06 - mae: 7.2948e-04 - val_loss: 1.4575e-06 - val_mae: 3.5130e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/30
#
# Epoch 1: val_loss did not improve from 0.00000
# 3510/3510 - 16s - 4ms/step - loss: 7.7212e-06 - mae: 0.0010 - val_loss: 4.7565e-06 - val_mae: 8.5631e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/36
#
# Epoch 1: val_loss did not improve from 0.00000
# 3487/3487 - 16s - 4ms/step - loss: 7.0731e-06 - mae: 9.8423e-04 - val_loss: 3.0592e-06 - val_mae: 6.0849e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/28
#
# Epoch 1: val_loss did not improve from 0.00000
# 3500/3500 - 16s - 4ms/step - loss: 6.4889e-06 - mae: 9.6728e-04 - val_loss: 3.5052e-06 - val_mae: 5.4880e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/27
#
# Epoch 1: val_loss did not improve from 0.00000
# 3458/3458 - 15s - 4ms/step - loss: 8.4448e-06 - mae: 0.0011 - val_loss: 1.1947e-05 - val_mae: 0.0010 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/29
#
# Epoch 1: val_loss did not improve from 0.00000
# 3489/3489 - 16s - 5ms/step - loss: 6.7569e-06 - mae: 0.0011 - val_loss: 5.8810e-06 - val_mae: 8.6552e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/33
#
# Epoch 1: val_loss did not improve from 0.00000
# 3473/3473 - 16s - 5ms/step - loss: 4.8486e-06 - mae: 8.2601e-04 - val_loss: 3.7366e-06 - val_mae: 6.4506e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/26
#
# Epoch 1: val_loss did not improve from 0.00000
# 3497/3497 - 16s - 4ms/step - loss: 6.2848e-06 - mae: 0.0010 - val_loss: 4.1334e-06 - val_mae: 7.5861e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/31
#
# Epoch 1: val_loss did not improve from 0.00000
# 3558/3558 - 16s - 4ms/step - loss: 5.6650e-06 - mae: 9.2446e-04 - val_loss: 2.9145e-06 - val_mae: 6.4019e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/37
#
# Epoch 1: val_loss did not improve from 0.00000
# 3635/3635 - 16s - 4ms/step - loss: 6.8546e-06 - mae: 9.3600e-04 - val_loss: 2.6763e-06 - val_mae: 5.8357e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/23
#
# Epoch 1: val_loss did not improve from 0.00000
# 3644/3644 - 16s - 5ms/step - loss: 7.0496e-06 - mae: 0.0010 - val_loss: 4.0973e-06 - val_mae: 7.4701e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/39
#
# Epoch 1: val_loss did not improve from 0.00000
# 3407/3407 - 15s - 4ms/step - loss: 8.7019e-06 - mae: 0.0011 - val_loss: 7.1334e-06 - val_mae: 8.6287e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/24
#
# Epoch 1: val_loss did not improve from 0.00000
# 3496/3496 - 16s - 4ms/step - loss: 7.7778e-06 - mae: 0.0011 - val_loss: 6.7449e-06 - val_mae: 9.4473e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/34
#
# Epoch 1: val_loss did not improve from 0.00000
# 3549/3549 - 16s - 5ms/step - loss: 8.8066e-06 - mae: 0.0011 - val_loss: 5.5273e-06 - val_mae: 6.9403e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/41
#
# Epoch 1: val_loss did not improve from 0.00000
# 3373/3373 - 15s - 4ms/step - loss: 7.1505e-06 - mae: 0.0010 - val_loss: 9.7112e-06 - val_mae: 0.0012 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/38
#
# Epoch 1: val_loss did not improve from 0.00000
# 3353/3353 - 15s - 4ms/step - loss: 5.8719e-06 - mae: 8.8665e-04 - val_loss: 5.6459e-06 - val_mae: 6.7916e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/43
#
# Epoch 1: val_loss did not improve from 0.00000
# 3513/3513 - 16s - 5ms/step - loss: 7.8875e-06 - mae: 0.0011 - val_loss: 4.1414e-06 - val_mae: 6.0482e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/40
#
# Epoch 1: val_loss did not improve from 0.00000
# 3434/3434 - 15s - 4ms/step - loss: 7.9039e-06 - mae: 0.0011 - val_loss: 5.0745e-06 - val_mae: 5.7952e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/42
#
# Epoch 1: val_loss did not improve from 0.00000
# 3378/3378 - 15s - 4ms/step - loss: 5.6738e-06 - mae: 8.5222e-04 - val_loss: 3.8217e-06 - val_mae: 6.5210e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/45
#
# Epoch 1: val_loss did not improve from 0.00000
# 3327/3327 - 15s - 4ms/step - loss: 5.8943e-06 - mae: 9.0314e-04 - val_loss: 2.1688e-06 - val_mae: 4.4298e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/25
#
# Epoch 1: val_loss did not improve from 0.00000
# 3520/3520 - 16s - 5ms/step - loss: 8.3412e-06 - mae: 0.0011 - val_loss: 4.1993e-06 - val_mae: 5.9601e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/49
#
# Epoch 1: val_loss did not improve from 0.00000
# 3368/3368 - 15s - 4ms/step - loss: 5.4056e-06 - mae: 8.8922e-04 - val_loss: 3.9918e-06 - val_mae: 7.1626e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/48
#
# Epoch 1: val_loss did not improve from 0.00000
# 3504/3504 - 16s - 4ms/step - loss: 7.5411e-06 - mae: 0.0010 - val_loss: 3.2356e-06 - val_mae: 6.0226e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/21
#
# Epoch 1: val_loss did not improve from 0.00000
# 3501/3501 - 16s - 4ms/step - loss: 7.1238e-06 - mae: 0.0011 - val_loss: 1.5709e-05 - val_mae: 0.0013 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/50
#
# Epoch 1: val_loss did not improve from 0.00000
# 3406/3406 - 15s - 4ms/step - loss: 6.1536e-06 - mae: 9.1113e-04 - val_loss: 2.6445e-06 - val_mae: 5.2320e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/32
#
# Epoch 1: val_loss did not improve from 0.00000
# 3592/3592 - 16s - 5ms/step - loss: 7.9983e-06 - mae: 0.0011 - val_loss: 4.8062e-06 - val_mae: 8.3079e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/35
#
# Epoch 1: val_loss did not improve from 0.00000
# 3475/3475 - 16s - 5ms/step - loss: 5.7865e-06 - mae: 9.4299e-04 - val_loss: 9.8208e-06 - val_mae: 9.3144e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/22
#
# Epoch 1: val_loss did not improve from 0.00000
# 3631/3631 - 16s - 4ms/step - loss: 8.2766e-06 - mae: 0.0012 - val_loss: 5.9727e-06 - val_mae: 8.0292e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/44
#
# Epoch 1: val_loss did not improve from 0.00000
# 3505/3505 - 16s - 4ms/step - loss: 7.3543e-06 - mae: 0.0010 - val_loss: 5.6198e-06 - val_mae: 8.9785e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/47
#
# Epoch 1: val_loss did not improve from 0.00000
# 3498/3498 - 16s - 5ms/step - loss: 7.0177e-06 - mae: 9.3396e-04 - val_loss: 2.8586e-06 - val_mae: 5.9465e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/46
#
# Epoch 1: val_loss did not improve from 0.00000
# 3389/3389 - 15s - 4ms/step - loss: 4.6871e-06 - mae: 8.0913e-04 - val_loss: 2.0835e-06 - val_mae: 4.8668e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/59
#
# Epoch 1: val_loss did not improve from 0.00000
# 3377/3377 - 15s - 5ms/step - loss: 5.0555e-06 - mae: 8.0014e-04 - val_loss: 2.7699e-06 - val_mae: 4.9847e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/62
#
# Epoch 1: val_loss did not improve from 0.00000
# 3468/3468 - 16s - 4ms/step - loss: 7.8564e-06 - mae: 0.0010 - val_loss: 3.7454e-06 - val_mae: 5.8525e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/57
#
# Epoch 1: val_loss did not improve from 0.00000
# 3561/3561 - 16s - 5ms/step - loss: 5.4879e-06 - mae: 8.7029e-04 - val_loss: 2.7660e-06 - val_mae: 4.8968e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/55
#
# Epoch 1: val_loss did not improve from 0.00000
# 3481/3481 - 16s - 4ms/step - loss: 7.3266e-06 - mae: 9.9670e-04 - val_loss: 2.4917e-06 - val_mae: 4.6399e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/63
#
# Epoch 1: val_loss did not improve from 0.00000
# 3415/3415 - 15s - 4ms/step - loss: 5.4580e-06 - mae: 8.5916e-04 - val_loss: 3.1242e-06 - val_mae: 6.2945e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/80
#
# Epoch 1: val_loss did not improve from 0.00000
# 3389/3389 - 15s - 4ms/step - loss: 7.8727e-06 - mae: 0.0010 - val_loss: 2.1029e-05 - val_mae: 0.0017 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/52
#
# Epoch 1: val_loss did not improve from 0.00000
# 3410/3410 - 15s - 4ms/step - loss: 6.7152e-06 - mae: 9.2876e-04 - val_loss: 3.5717e-06 - val_mae: 6.1640e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/88
#
# Epoch 1: val_loss did not improve from 0.00000
# 3447/3447 - 16s - 4ms/step - loss: 5.9850e-06 - mae: 9.4365e-04 - val_loss: 3.4072e-06 - val_mae: 7.2861e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/81
#
# Epoch 1: val_loss did not improve from 0.00000
# 3360/3360 - 15s - 4ms/step - loss: 5.3289e-06 - mae: 8.2517e-04 - val_loss: 4.5714e-06 - val_mae: 6.2370e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/54
#
# Epoch 1: val_loss did not improve from 0.00000
# 3362/3362 - 15s - 4ms/step - loss: 6.1792e-06 - mae: 9.0353e-04 - val_loss: 5.2923e-06 - val_mae: 6.5380e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/56
#
# Epoch 1: val_loss did not improve from 0.00000
# 3444/3444 - 15s - 4ms/step - loss: 5.5815e-06 - mae: 8.4235e-04 - val_loss: 4.3956e-06 - val_mae: 7.5234e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/73
#
# Epoch 1: val_loss did not improve from 0.00000
# 3408/3408 - 15s - 4ms/step - loss: 6.1529e-06 - mae: 8.4542e-04 - val_loss: 2.5816e-06 - val_mae: 4.7087e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/51
#
# Epoch 1: val_loss did not improve from 0.00000
# 3451/3451 - 16s - 4ms/step - loss: 8.4494e-06 - mae: 0.0011 - val_loss: 2.8514e-06 - val_mae: 4.8699e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/94
#
# Epoch 1: val_loss did not improve from 0.00000
# 3477/3477 - 16s - 5ms/step - loss: 7.7763e-06 - mae: 9.9636e-04 - val_loss: 5.4583e-06 - val_mae: 8.5271e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/72
#
# Epoch 1: val_loss did not improve from 0.00000
# 3387/3387 - 15s - 4ms/step - loss: 5.5873e-06 - mae: 8.6636e-04 - val_loss: 1.9678e-06 - val_mae: 4.3774e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/58
#
# Epoch 1: val_loss did not improve from 0.00000
# 3436/3436 - 15s - 4ms/step - loss: 4.7789e-06 - mae: 7.9714e-04 - val_loss: 3.2126e-05 - val_mae: 0.0016 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/61
#
# Epoch 1: val_loss did not improve from 0.00000
# 3462/3462 - 15s - 4ms/step - loss: 8.4506e-06 - mae: 0.0011 - val_loss: 4.9058e-06 - val_mae: 7.0671e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/95
#
# Epoch 1: val_loss did not improve from 0.00000
# 3374/3374 - 15s - 5ms/step - loss: 6.4953e-06 - mae: 8.9823e-04 - val_loss: 3.2230e-06 - val_mae: 5.8007e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/78
#
# Epoch 1: val_loss did not improve from 0.00000
# 3262/3262 - 15s - 4ms/step - loss: 5.0813e-06 - mae: 8.6988e-04 - val_loss: 2.6871e-06 - val_mae: 5.1061e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/60
#
# Epoch 1: val_loss did not improve from 0.00000
# 3421/3421 - 15s - 5ms/step - loss: 5.4912e-06 - mae: 8.3474e-04 - val_loss: 6.8595e-06 - val_mae: 7.9118e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/93
#
# Epoch 1: val_loss did not improve from 0.00000
# 3396/3396 - 15s - 5ms/step - loss: 6.4774e-06 - mae: 9.6422e-04 - val_loss: 3.3055e-06 - val_mae: 5.6548e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/67
#
# Epoch 1: val_loss did not improve from 0.00000
# 3440/3440 - 15s - 5ms/step - loss: 7.2816e-06 - mae: 9.7403e-04 - val_loss: 3.8522e-06 - val_mae: 5.1069e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/77
#
# Epoch 1: val_loss did not improve from 0.00000
# 3307/3307 - 15s - 4ms/step - loss: 6.7786e-06 - mae: 9.4091e-04 - val_loss: 3.4830e-06 - val_mae: 5.6948e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/68
#
# Epoch 1: val_loss did not improve from 0.00000
# 3388/3388 - 15s - 4ms/step - loss: 5.0526e-06 - mae: 8.6000e-04 - val_loss: 3.0703e-06 - val_mae: 6.7983e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/65
#
# Epoch 1: val_loss did not improve from 0.00000
# 3444/3444 - 15s - 4ms/step - loss: 8.0487e-06 - mae: 0.0011 - val_loss: 1.3289e-05 - val_mae: 0.0012 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/64
#
# Epoch 1: val_loss did not improve from 0.00000
# 3334/3334 - 15s - 5ms/step - loss: 5.5073e-06 - mae: 9.2103e-04 - val_loss: 4.9557e-06 - val_mae: 7.6023e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/83
#
# Epoch 1: val_loss did not improve from 0.00000
# 3449/3449 - 16s - 5ms/step - loss: 6.8216e-06 - mae: 9.4119e-04 - val_loss: 7.6748e-06 - val_mae: 7.3799e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/66
#
# Epoch 1: val_loss did not improve from 0.00000
# 3391/3391 - 15s - 4ms/step - loss: 6.4413e-06 - mae: 9.3168e-04 - val_loss: 2.9440e-06 - val_mae: 4.8375e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/98
#
# Epoch 1: val_loss did not improve from 0.00000
# 3405/3405 - 15s - 5ms/step - loss: 6.3113e-06 - mae: 9.2364e-04 - val_loss: 3.2996e-06 - val_mae: 5.9916e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/70
#
# Epoch 1: val_loss did not improve from 0.00000
# 3458/3458 - 15s - 4ms/step - loss: 7.0832e-06 - mae: 9.8566e-04 - val_loss: 4.8992e-06 - val_mae: 7.3627e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/89
#
# Epoch 1: val_loss did not improve from 0.00000
# 3354/3354 - 15s - 4ms/step - loss: 6.4404e-06 - mae: 8.9947e-04 - val_loss: 3.4187e-06 - val_mae: 4.9295e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/100
#
# Epoch 1: val_loss did not improve from 0.00000
# 3459/3459 - 16s - 5ms/step - loss: 9.1250e-06 - mae: 0.0011 - val_loss: 3.0909e-06 - val_mae: 5.4524e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/75
#
# Epoch 1: val_loss did not improve from 0.00000
# 3385/3385 - 15s - 4ms/step - loss: 5.4811e-06 - mae: 8.5326e-04 - val_loss: 2.9021e-06 - val_mae: 4.9765e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/91
#
# Epoch 1: val_loss did not improve from 0.00000
# 3542/3542 - 16s - 4ms/step - loss: 8.7438e-06 - mae: 0.0011 - val_loss: 4.8112e-06 - val_mae: 6.7530e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/99
#
# Epoch 1: val_loss did not improve from 0.00000
# 3357/3357 - 15s - 4ms/step - loss: 6.0150e-06 - mae: 8.7369e-04 - val_loss: 5.8272e-06 - val_mae: 8.5908e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/96
#
# Epoch 1: val_loss did not improve from 0.00000
# 3472/3472 - 16s - 4ms/step - loss: 8.3090e-06 - mae: 0.0011 - val_loss: 5.7813e-06 - val_mae: 8.8916e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/53
#
# Epoch 1: val_loss did not improve from 0.00000
# 3466/3466 - 16s - 4ms/step - loss: 6.8868e-06 - mae: 9.2255e-04 - val_loss: 2.9055e-06 - val_mae: 4.9987e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/90
#
# Epoch 1: val_loss did not improve from 0.00000
# 3416/3416 - 15s - 5ms/step - loss: 4.8517e-06 - mae: 8.5320e-04 - val_loss: 3.2734e-06 - val_mae: 6.2940e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/97
#
# Epoch 1: val_loss did not improve from 0.00000
# 3424/3424 - 15s - 4ms/step - loss: 7.1911e-06 - mae: 9.7238e-04 - val_loss: 3.8460e-06 - val_mae: 6.2430e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/74
#
# Epoch 1: val_loss did not improve from 0.00000
# 3371/3371 - 15s - 4ms/step - loss: 7.3739e-06 - mae: 9.8128e-04 - val_loss: 3.3320e-06 - val_mae: 4.9108e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/79
#
# Epoch 1: val_loss did not improve from 0.00000
# 3501/3501 - 16s - 5ms/step - loss: 7.1060e-06 - mae: 9.7969e-04 - val_loss: 1.0061e-05 - val_mae: 0.0011 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/69
#
# Epoch 1: val_loss did not improve from 0.00000
# 3515/3515 - 16s - 4ms/step - loss: 8.1138e-06 - mae: 0.0010 - val_loss: 4.3495e-06 - val_mae: 7.3069e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/82
#
# Epoch 1: val_loss did not improve from 0.00000
# 3508/3508 - 16s - 4ms/step - loss: 7.0494e-06 - mae: 9.7079e-04 - val_loss: 5.1308e-06 - val_mae: 9.1348e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/84
#
# Epoch 1: val_loss did not improve from 0.00000
# 3351/3351 - 15s - 4ms/step - loss: 7.1035e-06 - mae: 9.8969e-04 - val_loss: 3.9671e-06 - val_mae: 6.8894e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/87
#
# Epoch 1: val_loss did not improve from 0.00000
# 3402/3402 - 15s - 5ms/step - loss: 6.3724e-06 - mae: 9.5773e-04 - val_loss: 3.8806e-06 - val_mae: 7.0178e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/85
#
# Epoch 1: val_loss did not improve from 0.00000
# 3536/3536 - 16s - 4ms/step - loss: 7.6623e-06 - mae: 0.0011 - val_loss: 4.2176e-06 - val_mae: 7.3284e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/71
#
# Epoch 1: val_loss did not improve from 0.00000
# 3428/3428 - 15s - 4ms/step - loss: 6.3624e-06 - mae: 9.5374e-04 - val_loss: 3.2412e-06 - val_mae: 5.9982e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/76
#
# Epoch 1: val_loss did not improve from 0.00000
# 3491/3491 - 16s - 4ms/step - loss: 5.7304e-06 - mae: 8.8573e-04 - val_loss: 4.6666e-06 - val_mae: 8.0130e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/86
#
# Epoch 1: val_loss did not improve from 0.00000
# 3377/3377 - 15s - 4ms/step - loss: 6.3212e-06 - mae: 9.4431e-04 - val_loss: 3.1029e-06 - val_mae: 5.5728e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/92
#
# Epoch 1: val_loss did not improve from 0.00000
# 3386/3386 - 15s - 4ms/step - loss: 6.2371e-06 - mae: 9.3039e-04 - val_loss: 6.6927e-06 - val_mae: 7.9291e-04 - learning_rate: 1.0000e-03
# -----------------------------------
# Epoch: 1
# -----------------------------------
# Processing: snapshots/strategy2/5
#
# Epoch 1: val_loss did not improve from 0.00000
# 3578/3578 - 16s - 4ms/step - loss: 7.4794e-06 - mae: 0.0010 - val_loss: 4.2642e-06 - val_mae: 7.7682e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/3
#
# Epoch 1: val_loss did not improve from 0.00000
# 3539/3539 - 16s - 4ms/step - loss: 6.6675e-06 - mae: 9.4668e-04 - val_loss: 3.2713e-06 - val_mae: 5.4735e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/2
#
# Epoch 1: val_loss did not improve from 0.00000
# 3325/3325 - 15s - 4ms/step - loss: 7.3823e-06 - mae: 0.0010 - val_loss: 6.2820e-06 - val_mae: 8.6243e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/4
#
# Epoch 1: val_loss did not improve from 0.00000
# 3456/3456 - 15s - 4ms/step - loss: 7.0614e-06 - mae: 0.0010 - val_loss: 1.3688e-05 - val_mae: 0.0013 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/1
#
# Epoch 1: val_loss did not improve from 0.00000
# 3317/3317 - 15s - 4ms/step - loss: 7.3254e-06 - mae: 9.9430e-04 - val_loss: 7.4226e-06 - val_mae: 9.7297e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/8
#
# Epoch 1: val_loss did not improve from 0.00000
# 3506/3506 - 16s - 5ms/step - loss: 6.8034e-06 - mae: 9.0084e-04 - val_loss: 2.7341e-06 - val_mae: 5.1675e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/7
#
# Epoch 1: val_loss did not improve from 0.00000
# 3508/3508 - 16s - 4ms/step - loss: 7.0805e-06 - mae: 9.8920e-04 - val_loss: 3.3217e-06 - val_mae: 5.6575e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/14
#
# Epoch 1: val_loss did not improve from 0.00000
# 3538/3538 - 16s - 4ms/step - loss: 7.7219e-06 - mae: 0.0010 - val_loss: 6.2825e-06 - val_mae: 9.1740e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/17
#
# Epoch 1: val_loss did not improve from 0.00000
# 3487/3487 - 16s - 4ms/step - loss: 5.2688e-06 - mae: 8.4828e-04 - val_loss: 1.9253e-06 - val_mae: 4.7876e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/12
#
# Epoch 1: val_loss did not improve from 0.00000
# 3393/3393 - 15s - 4ms/step - loss: 9.7353e-06 - mae: 0.0011 - val_loss: 8.0350e-06 - val_mae: 8.9768e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/11
#
# Epoch 1: val_loss did not improve from 0.00000
# 3504/3504 - 16s - 5ms/step - loss: 9.1849e-06 - mae: 0.0011 - val_loss: 4.7864e-06 - val_mae: 6.8113e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/10
#
# Epoch 1: val_loss did not improve from 0.00000
# 3446/3446 - 16s - 5ms/step - loss: 8.1027e-06 - mae: 9.8810e-04 - val_loss: 3.2060e-06 - val_mae: 4.3312e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/15
#
# Epoch 1: val_loss did not improve from 0.00000
# 3564/3564 - 16s - 4ms/step - loss: 6.9979e-06 - mae: 0.0010 - val_loss: 3.6459e-06 - val_mae: 6.0276e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/6
#
# Epoch 1: val_loss did not improve from 0.00000
# 3432/3432 - 15s - 4ms/step - loss: 6.6761e-06 - mae: 9.9218e-04 - val_loss: 4.0376e-06 - val_mae: 6.9419e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/9
#
# Epoch 1: val_loss did not improve from 0.00000
# 3425/3425 - 15s - 4ms/step - loss: 4.7705e-06 - mae: 8.5918e-04 - val_loss: 4.8396e-05 - val_mae: 0.0023 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/16
#
# Epoch 1: val_loss did not improve from 0.00000
# 3416/3416 - 15s - 4ms/step - loss: 9.2778e-06 - mae: 0.0012 - val_loss: 6.5300e-06 - val_mae: 8.3912e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/20
#
# Epoch 1: val_loss did not improve from 0.00000
# 3503/3503 - 16s - 4ms/step - loss: 5.6403e-06 - mae: 9.4662e-04 - val_loss: 5.6237e-06 - val_mae: 8.1161e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/19
#
# Epoch 1: val_loss did not improve from 0.00000
# 5774/5774 - 26s - 4ms/step - loss: 1.4100e-04 - mae: 0.0030 - val_loss: 4.8662e-05 - val_mae: 0.0019 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/18
#
# Epoch 1: val_loss did not improve from 0.00000
# 3409/3409 - 15s - 4ms/step - loss: 1.1312e-05 - mae: 0.0012 - val_loss: 3.6671e-06 - val_mae: 6.5152e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/13
#
# Epoch 1: val_loss did not improve from 0.00000
# 3292/3292 - 15s - 4ms/step - loss: 3.9965e-06 - mae: 7.1963e-04 - val_loss: 1.6493e-06 - val_mae: 3.8125e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/30
#
# Epoch 1: val_loss did not improve from 0.00000
# 3510/3510 - 16s - 4ms/step - loss: 7.5474e-06 - mae: 0.0010 - val_loss: 4.1578e-06 - val_mae: 7.3669e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/36
#
# Epoch 1: val_loss did not improve from 0.00000
# 3487/3487 - 16s - 4ms/step - loss: 6.6110e-06 - mae: 9.9008e-04 - val_loss: 2.5208e-06 - val_mae: 5.3123e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/28
#
# Epoch 1: val_loss did not improve from 0.00000
# 3500/3500 - 16s - 5ms/step - loss: 6.2530e-06 - mae: 9.6533e-04 - val_loss: 2.4688e-06 - val_mae: 4.9074e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/27
#
# Epoch 1: val_loss did not improve from 0.00000
# 3458/3458 - 15s - 4ms/step - loss: 8.5290e-06 - mae: 0.0010 - val_loss: 1.2518e-05 - val_mae: 0.0010 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/29
#
# Epoch 1: val_loss did not improve from 0.00000
# 3489/3489 - 16s - 4ms/step - loss: 6.8837e-06 - mae: 0.0011 - val_loss: 6.1087e-06 - val_mae: 8.6600e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/33
#
# Epoch 1: val_loss did not improve from 0.00000
# 3473/3473 - 15s - 4ms/step - loss: 4.6504e-06 - mae: 7.9271e-04 - val_loss: 3.1306e-06 - val_mae: 5.6132e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/26
#
# Epoch 1: val_loss did not improve from 0.00000
# 3497/3497 - 16s - 4ms/step - loss: 5.7655e-06 - mae: 9.6332e-04 - val_loss: 3.7631e-06 - val_mae: 7.2622e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/31
#
# Epoch 1: val_loss did not improve from 0.00000
# 3558/3558 - 16s - 4ms/step - loss: 5.8948e-06 - mae: 9.1458e-04 - val_loss: 3.6125e-06 - val_mae: 6.1382e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/37
#
# Epoch 1: val_loss did not improve from 0.00000
# 3635/3635 - 16s - 4ms/step - loss: 6.5511e-06 - mae: 9.4302e-04 - val_loss: 2.4739e-06 - val_mae: 5.3508e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/23
#
# Epoch 1: val_loss did not improve from 0.00000
# 3644/3644 - 16s - 4ms/step - loss: 6.9702e-06 - mae: 9.8337e-04 - val_loss: 7.1141e-06 - val_mae: 0.0011 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/39
#
# Epoch 1: val_loss did not improve from 0.00000
# 3407/3407 - 15s - 4ms/step - loss: 8.3767e-06 - mae: 0.0011 - val_loss: 6.3504e-06 - val_mae: 7.7988e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/24
#
# Epoch 1: val_loss did not improve from 0.00000
# 3496/3496 - 16s - 5ms/step - loss: 7.5849e-06 - mae: 0.0011 - val_loss: 7.8938e-06 - val_mae: 9.9740e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/34
#
# Epoch 1: val_loss did not improve from 0.00000
# 3549/3549 - 16s - 4ms/step - loss: 8.4152e-06 - mae: 0.0011 - val_loss: 5.6804e-06 - val_mae: 7.2288e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/41
#
# Epoch 1: val_loss did not improve from 0.00000
# 3373/3373 - 15s - 4ms/step - loss: 7.6053e-06 - mae: 0.0010 - val_loss: 1.0090e-05 - val_mae: 0.0012 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/38
#
# Epoch 1: val_loss did not improve from 0.00000
# 3353/3353 - 15s - 4ms/step - loss: 5.8982e-06 - mae: 8.9245e-04 - val_loss: 5.4610e-06 - val_mae: 6.6091e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/43
#
# Epoch 1: val_loss did not improve from 0.00000
# 3513/3513 - 16s - 4ms/step - loss: 8.1079e-06 - mae: 0.0011 - val_loss: 4.9518e-06 - val_mae: 7.5337e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/40
#
# Epoch 1: val_loss did not improve from 0.00000
# 3434/3434 - 16s - 5ms/step - loss: 7.9450e-06 - mae: 0.0011 - val_loss: 5.1440e-06 - val_mae: 6.1875e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/42
#
# Epoch 1: val_loss did not improve from 0.00000
# 3378/3378 - 15s - 4ms/step - loss: 5.4932e-06 - mae: 8.6236e-04 - val_loss: 4.0043e-06 - val_mae: 6.9249e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/45
#
# Epoch 1: val_loss did not improve from 0.00000
# 3327/3327 - 15s - 4ms/step - loss: 5.9070e-06 - mae: 9.0030e-04 - val_loss: 2.3082e-06 - val_mae: 4.6383e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/25
#
# Epoch 1: val_loss did not improve from 0.00000
# 3520/3520 - 16s - 5ms/step - loss: 7.9557e-06 - mae: 0.0011 - val_loss: 4.6857e-06 - val_mae: 6.3392e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/49
#
# Epoch 1: val_loss did not improve from 0.00000
# 3368/3368 - 15s - 5ms/step - loss: 5.4671e-06 - mae: 8.8699e-04 - val_loss: 3.5044e-06 - val_mae: 6.5598e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/48
#
# Epoch 1: val_loss did not improve from 0.00000
# 3504/3504 - 16s - 5ms/step - loss: 7.6001e-06 - mae: 0.0010 - val_loss: 4.8046e-06 - val_mae: 8.0216e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/21
#
# Epoch 1: val_loss did not improve from 0.00000
# 3501/3501 - 16s - 5ms/step - loss: 7.3262e-06 - mae: 0.0011 - val_loss: 1.5544e-05 - val_mae: 0.0013 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/50
#
# Epoch 1: val_loss did not improve from 0.00000
# 3406/3406 - 15s - 5ms/step - loss: 6.5770e-06 - mae: 9.2768e-04 - val_loss: 2.8457e-06 - val_mae: 5.5217e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/32
#
# Epoch 1: val_loss did not improve from 0.00000
# 3592/3592 - 16s - 5ms/step - loss: 8.3067e-06 - mae: 0.0011 - val_loss: 4.2808e-06 - val_mae: 7.9397e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/35
#
# Epoch 1: val_loss did not improve from 0.00000
# 3475/3475 - 16s - 5ms/step - loss: 5.7806e-06 - mae: 9.3245e-04 - val_loss: 9.5730e-06 - val_mae: 8.9822e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/22
#
# Epoch 1: val_loss did not improve from 0.00000
# 3631/3631 - 16s - 5ms/step - loss: 8.4277e-06 - mae: 0.0012 - val_loss: 5.4330e-06 - val_mae: 7.4376e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/44
#
# Epoch 1: val_loss did not improve from 0.00000
# 3505/3505 - 16s - 5ms/step - loss: 7.4403e-06 - mae: 0.0010 - val_loss: 5.3815e-06 - val_mae: 8.9855e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/47
#
# Epoch 1: val_loss did not improve from 0.00000
# 3498/3498 - 16s - 5ms/step - loss: 6.2811e-06 - mae: 8.8279e-04 - val_loss: 2.8668e-06 - val_mae: 5.7295e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/46
#
# Epoch 1: val_loss did not improve from 0.00000
# 3389/3389 - 15s - 5ms/step - loss: 4.7307e-06 - mae: 8.0890e-04 - val_loss: 2.4731e-06 - val_mae: 5.3150e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/59
#
# Epoch 1: val_loss did not improve from 0.00000
# 3377/3377 - 16s - 5ms/step - loss: 5.0383e-06 - mae: 7.9586e-04 - val_loss: 3.4149e-06 - val_mae: 5.2081e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/62
#
# Epoch 1: val_loss did not improve from 0.00000
# 3468/3468 - 16s - 5ms/step - loss: 7.8090e-06 - mae: 0.0010 - val_loss: 4.2338e-06 - val_mae: 6.0572e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/57
#
# Epoch 1: val_loss did not improve from 0.00000
# 3561/3561 - 16s - 5ms/step - loss: 5.4346e-06 - mae: 8.4880e-04 - val_loss: 3.0553e-06 - val_mae: 6.8769e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/55
#
# Epoch 1: val_loss did not improve from 0.00000
# 3481/3481 - 16s - 5ms/step - loss: 6.7096e-06 - mae: 9.4062e-04 - val_loss: 2.6623e-06 - val_mae: 4.7769e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/63
#
# Epoch 1: val_loss did not improve from 0.00000
# 3415/3415 - 15s - 5ms/step - loss: 5.3424e-06 - mae: 8.2985e-04 - val_loss: 2.4206e-06 - val_mae: 5.1610e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/80
#
# Epoch 1: val_loss did not improve from 0.00000
# 3389/3389 - 15s - 5ms/step - loss: 7.7105e-06 - mae: 9.8423e-04 - val_loss: 2.0881e-05 - val_mae: 0.0017 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/52
#
# Epoch 1: val_loss did not improve from 0.00000
# 3410/3410 - 15s - 5ms/step - loss: 6.7461e-06 - mae: 9.2246e-04 - val_loss: 3.6884e-06 - val_mae: 5.9134e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/88
#
# Epoch 1: val_loss did not improve from 0.00000
# 3447/3447 - 16s - 5ms/step - loss: 5.9414e-06 - mae: 9.1928e-04 - val_loss: 3.7643e-06 - val_mae: 7.4423e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/81
#
# Epoch 1: val_loss did not improve from 0.00000
# 3360/3360 - 15s - 5ms/step - loss: 5.6289e-06 - mae: 8.5363e-04 - val_loss: 5.1260e-06 - val_mae: 6.6938e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/54
#
# Epoch 1: val_loss did not improve from 0.00000
# 3362/3362 - 15s - 5ms/step - loss: 6.0285e-06 - mae: 9.0809e-04 - val_loss: 5.5367e-06 - val_mae: 6.8129e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/56
#
# Epoch 1: val_loss did not improve from 0.00000
# 3444/3444 - 16s - 5ms/step - loss: 5.5183e-06 - mae: 8.2532e-04 - val_loss: 2.8864e-06 - val_mae: 5.8585e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/73
#
# Epoch 1: val_loss did not improve from 0.00000
# 3408/3408 - 15s - 5ms/step - loss: 5.9300e-06 - mae: 8.3256e-04 - val_loss: 3.0024e-06 - val_mae: 5.2141e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/51
#
# Epoch 1: val_loss did not improve from 0.00000
# 3451/3451 - 16s - 5ms/step - loss: 7.7550e-06 - mae: 0.0011 - val_loss: 3.1857e-06 - val_mae: 5.4405e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/94
#
# Epoch 1: val_loss did not improve from 0.00000
# 3477/3477 - 16s - 5ms/step - loss: 7.0261e-06 - mae: 9.6494e-04 - val_loss: 4.5396e-06 - val_mae: 7.7299e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/72
#
# Epoch 1: val_loss did not improve from 0.00000
# 3387/3387 - 15s - 5ms/step - loss: 5.4424e-06 - mae: 8.3870e-04 - val_loss: 3.3655e-06 - val_mae: 6.4797e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/58
#
# Epoch 1: val_loss did not improve from 0.00000
# 3436/3436 - 16s - 5ms/step - loss: 5.1011e-06 - mae: 8.0547e-04 - val_loss: 3.3840e-05 - val_mae: 0.0017 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/61
#
# Epoch 1: val_loss did not improve from 0.00000
# 3462/3462 - 16s - 5ms/step - loss: 8.3732e-06 - mae: 0.0010 - val_loss: 5.3265e-06 - val_mae: 7.3689e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/95
#
# Epoch 1: val_loss did not improve from 0.00000
# 3374/3374 - 15s - 5ms/step - loss: 6.4260e-06 - mae: 8.8490e-04 - val_loss: 2.5874e-06 - val_mae: 5.0444e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/78
#
# Epoch 1: val_loss did not improve from 0.00000
# 3262/3262 - 15s - 5ms/step - loss: 5.2298e-06 - mae: 8.8197e-04 - val_loss: 3.1026e-06 - val_mae: 5.7959e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/60
#
# Epoch 1: val_loss did not improve from 0.00000
# 3421/3421 - 15s - 5ms/step - loss: 5.5331e-06 - mae: 8.4510e-04 - val_loss: 7.3970e-06 - val_mae: 8.1898e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/93
#
# Epoch 1: val_loss did not improve from 0.00000
# 3396/3396 - 15s - 5ms/step - loss: 6.5934e-06 - mae: 9.3392e-04 - val_loss: 3.8835e-06 - val_mae: 6.6078e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/67
#
# Epoch 1: val_loss did not improve from 0.00000
# 3440/3440 - 16s - 5ms/step - loss: 7.1384e-06 - mae: 9.5986e-04 - val_loss: 4.7475e-06 - val_mae: 5.7027e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/77
#
# Epoch 1: val_loss did not improve from 0.00000
# 3307/3307 - 15s - 5ms/step - loss: 6.5513e-06 - mae: 9.1023e-04 - val_loss: 4.1806e-06 - val_mae: 6.7084e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/68
#
# Epoch 1: val_loss did not improve from 0.00000
# 3388/3388 - 15s - 5ms/step - loss: 4.6446e-06 - mae: 8.2581e-04 - val_loss: 2.4283e-06 - val_mae: 5.9150e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/65
#
# Epoch 1: val_loss did not improve from 0.00000
# 3444/3444 - 16s - 5ms/step - loss: 7.8830e-06 - mae: 0.0010 - val_loss: 1.5341e-05 - val_mae: 0.0012 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/64
#
# Epoch 1: val_loss did not improve from 0.00000
# 3334/3334 - 15s - 5ms/step - loss: 5.2621e-06 - mae: 8.9328e-04 - val_loss: 4.7183e-06 - val_mae: 7.5800e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/83
#
# Epoch 1: val_loss did not improve from 0.00000
# 3449/3449 - 16s - 5ms/step - loss: 6.4545e-06 - mae: 9.2557e-04 - val_loss: 7.6454e-06 - val_mae: 7.7709e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/66
#
# Epoch 1: val_loss did not improve from 0.00000
# 3391/3391 - 15s - 5ms/step - loss: 5.9001e-06 - mae: 8.8378e-04 - val_loss: 2.8626e-06 - val_mae: 4.8775e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/98
#
# Epoch 1: val_loss did not improve from 0.00000
# 3405/3405 - 15s - 5ms/step - loss: 6.6033e-06 - mae: 9.4048e-04 - val_loss: 3.0111e-06 - val_mae: 5.5125e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/70
#
# Epoch 1: val_loss did not improve from 0.00000
# 3458/3458 - 16s - 5ms/step - loss: 7.2256e-06 - mae: 9.7858e-04 - val_loss: 4.5430e-06 - val_mae: 7.1708e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/89
#
# Epoch 1: val_loss did not improve from 0.00000
# 3354/3354 - 15s - 5ms/step - loss: 5.9063e-06 - mae: 8.4266e-04 - val_loss: 3.4486e-06 - val_mae: 5.0326e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/100
#
# Epoch 1: val_loss did not improve from 0.00000
# 3459/3459 - 16s - 5ms/step - loss: 9.1512e-06 - mae: 0.0011 - val_loss: 2.7476e-06 - val_mae: 5.2760e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/75
#
# Epoch 1: val_loss did not improve from 0.00000
# 3385/3385 - 15s - 5ms/step - loss: 5.7308e-06 - mae: 8.5243e-04 - val_loss: 3.2623e-06 - val_mae: 5.2872e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/91
#
# Epoch 1: val_loss did not improve from 0.00000
# 3542/3542 - 16s - 5ms/step - loss: 8.1709e-06 - mae: 0.0010 - val_loss: 7.0755e-06 - val_mae: 9.4580e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/99
#
# Epoch 1: val_loss did not improve from 0.00000
# 3357/3357 - 15s - 5ms/step - loss: 5.8725e-06 - mae: 8.5595e-04 - val_loss: 6.7679e-06 - val_mae: 9.7699e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/96
#
# Epoch 1: val_loss did not improve from 0.00000
# 3472/3472 - 16s - 5ms/step - loss: 7.9008e-06 - mae: 0.0010 - val_loss: 7.7043e-06 - val_mae: 0.0011 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/53
#
# Epoch 1: val_loss did not improve from 0.00000
# 3466/3466 - 16s - 5ms/step - loss: 6.6194e-06 - mae: 8.7909e-04 - val_loss: 4.1824e-06 - val_mae: 6.1061e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/90
#
# Epoch 1: val_loss did not improve from 0.00000
# 3416/3416 - 15s - 5ms/step - loss: 4.7378e-06 - mae: 8.1309e-04 - val_loss: 2.8191e-06 - val_mae: 5.4604e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/97
#
# Epoch 1: val_loss did not improve from 0.00000
# 3424/3424 - 16s - 5ms/step - loss: 7.1076e-06 - mae: 9.4703e-04 - val_loss: 3.7365e-06 - val_mae: 5.5458e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/74
#
# Epoch 1: val_loss did not improve from 0.00000
# 3371/3371 - 15s - 5ms/step - loss: 7.3138e-06 - mae: 9.8627e-04 - val_loss: 3.2074e-06 - val_mae: 4.9646e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/79
#
# Epoch 1: val_loss did not improve from 0.00000
# 3501/3501 - 16s - 5ms/step - loss: 6.3568e-06 - mae: 9.1530e-04 - val_loss: 8.3401e-06 - val_mae: 9.0096e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/69
#
# Epoch 1: val_loss did not improve from 0.00000
# 3515/3515 - 16s - 5ms/step - loss: 7.8092e-06 - mae: 0.0010 - val_loss: 5.0666e-06 - val_mae: 8.4669e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/82
#
# Epoch 1: val_loss did not improve from 0.00000
# 3508/3508 - 16s - 5ms/step - loss: 6.6108e-06 - mae: 9.2164e-04 - val_loss: 3.3136e-06 - val_mae: 6.6399e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/84
#
# Epoch 1: val_loss did not improve from 0.00000
# 3351/3351 - 15s - 5ms/step - loss: 6.6967e-06 - mae: 9.6010e-04 - val_loss: 3.6423e-06 - val_mae: 6.3595e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/87
#
# Epoch 1: val_loss did not improve from 0.00000
# 3402/3402 - 15s - 5ms/step - loss: 5.8600e-06 - mae: 9.1741e-04 - val_loss: 4.5498e-06 - val_mae: 7.8638e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/85
#
# Epoch 1: val_loss did not improve from 0.00000
# 3536/3536 - 16s - 5ms/step - loss: 7.3970e-06 - mae: 0.0010 - val_loss: 7.2048e-06 - val_mae: 0.0010 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/71
#
# Epoch 1: val_loss did not improve from 0.00000
# 3428/3428 - 16s - 5ms/step - loss: 6.1983e-06 - mae: 9.3203e-04 - val_loss: 3.4886e-06 - val_mae: 6.3460e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/76
#
# Epoch 1: val_loss did not improve from 0.00000
# 3491/3491 - 16s - 5ms/step - loss: 5.9317e-06 - mae: 8.7853e-04 - val_loss: 4.8895e-06 - val_mae: 7.4574e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/86
#
# Epoch 1: val_loss did not improve from 0.00000
# 3377/3377 - 15s - 5ms/step - loss: 5.8780e-06 - mae: 9.0655e-04 - val_loss: 3.5601e-06 - val_mae: 6.1530e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/92
#
# Epoch 1: val_loss did not improve from 0.00000
# 3386/3386 - 15s - 5ms/step - loss: 5.6762e-06 - mae: 8.7089e-04 - val_loss: 5.1392e-06 - val_mae: 6.9161e-04 - learning_rate: 1.0000e-03
# -----------------------------------
# Epoch: 2
# -----------------------------------
# Processing: snapshots/strategy2/5
#
# Epoch 1: val_loss did not improve from 0.00000
# 3578/3578 - 16s - 5ms/step - loss: 7.2278e-06 - mae: 9.7558e-04 - val_loss: 2.2841e-06 - val_mae: 5.1584e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/3
#
# Epoch 1: val_loss did not improve from 0.00000
# 3539/3539 - 16s - 5ms/step - loss: 6.6652e-06 - mae: 9.2894e-04 - val_loss: 2.9844e-06 - val_mae: 5.3761e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/2
#
# Epoch 1: val_loss did not improve from 0.00000
# 3325/3325 - 15s - 5ms/step - loss: 7.2867e-06 - mae: 9.9920e-04 - val_loss: 5.4116e-06 - val_mae: 7.6471e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/4
#
# Epoch 1: val_loss did not improve from 0.00000
# 3456/3456 - 16s - 5ms/step - loss: 6.8142e-06 - mae: 9.6881e-04 - val_loss: 1.4298e-05 - val_mae: 0.0013 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/1
#
# Epoch 1: val_loss did not improve from 0.00000
# 3317/3317 - 15s - 5ms/step - loss: 7.3177e-06 - mae: 9.8616e-04 - val_loss: 7.9187e-06 - val_mae: 0.0010 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/8
#
# Epoch 1: val_loss did not improve from 0.00000
# 3506/3506 - 16s - 5ms/step - loss: 6.4287e-06 - mae: 8.7176e-04 - val_loss: 3.0496e-06 - val_mae: 4.9333e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/7
#
# Epoch 1: val_loss did not improve from 0.00000
# 3508/3508 - 16s - 5ms/step - loss: 6.9731e-06 - mae: 9.8848e-04 - val_loss: 4.0681e-06 - val_mae: 6.5418e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/14
#
# Epoch 1: val_loss did not improve from 0.00000
# 3538/3538 - 16s - 5ms/step - loss: 7.6185e-06 - mae: 0.0010 - val_loss: 6.7304e-06 - val_mae: 9.7752e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/17
#
# Epoch 1: val_loss did not improve from 0.00000
# 3487/3487 - 16s - 5ms/step - loss: 5.1542e-06 - mae: 8.4294e-04 - val_loss: 2.1675e-06 - val_mae: 4.4673e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/12
#
# Epoch 1: val_loss did not improve from 0.00000
# 3393/3393 - 15s - 5ms/step - loss: 9.5329e-06 - mae: 0.0011 - val_loss: 8.1268e-06 - val_mae: 9.0784e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/11
#
# Epoch 1: val_loss did not improve from 0.00000
# 3504/3504 - 16s - 5ms/step - loss: 9.1789e-06 - mae: 0.0011 - val_loss: 3.7665e-06 - val_mae: 5.7845e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/10
#
# Epoch 1: val_loss did not improve from 0.00000
# 3446/3446 - 16s - 5ms/step - loss: 7.6630e-06 - mae: 9.2819e-04 - val_loss: 3.8253e-06 - val_mae: 4.7017e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/15
#
# Epoch 1: val_loss did not improve from 0.00000
# 3564/3564 - 16s - 5ms/step - loss: 6.5167e-06 - mae: 9.9463e-04 - val_loss: 2.9491e-06 - val_mae: 5.7977e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/6
#
# Epoch 1: val_loss did not improve from 0.00000
# 3432/3432 - 16s - 5ms/step - loss: 5.9279e-06 - mae: 9.2514e-04 - val_loss: 3.6002e-06 - val_mae: 6.1864e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/9
#
# Epoch 1: val_loss did not improve from 0.00000
# 3425/3425 - 15s - 5ms/step - loss: 4.5319e-06 - mae: 8.3133e-04 - val_loss: 5.1116e-05 - val_mae: 0.0025 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/16
#
# Epoch 1: val_loss did not improve from 0.00000
# 3416/3416 - 15s - 5ms/step - loss: 8.7474e-06 - mae: 0.0011 - val_loss: 6.2239e-06 - val_mae: 8.3955e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/20
#
# Epoch 1: val_loss did not improve from 0.00000
# 3503/3503 - 16s - 5ms/step - loss: 5.4037e-06 - mae: 9.3055e-04 - val_loss: 6.1505e-06 - val_mae: 8.9022e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/19
#
# Epoch 1: val_loss did not improve from 0.00000
# 5774/5774 - 26s - 5ms/step - loss: 1.3476e-04 - mae: 0.0029 - val_loss: 4.3970e-05 - val_mae: 0.0018 - learning_rate: 1.0000e-03
# ...
# Processing: snapshots/strategy2/31
#
# Epoch 1: val_loss did not improve from 0.00000
# 3558/3558 - 16s - 5ms/step - loss: 4.6339e-06 - mae: 8.9517e-04 - val_loss: 2.6757e-06 - val_mae: 5.5261e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/37
#
# Epoch 1: val_loss did not improve from 0.00000
# 3635/3635 - 16s - 5ms/step - loss: 5.3033e-06 - mae: 9.3024e-04 - val_loss: 2.5532e-06 - val_mae: 5.7921e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/23
#
# Epoch 1: val_loss did not improve from 0.00000
# 3644/3644 - 16s - 5ms/step - loss: 6.0610e-06 - mae: 0.0010 - val_loss: 5.2646e-06 - val_mae: 8.9650e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/39
#
# Epoch 1: val_loss did not improve from 0.00000
# 3407/3407 - 15s - 5ms/step - loss: 7.0880e-06 - mae: 0.0011 - val_loss: 8.0075e-06 - val_mae: 9.0587e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/24
#
# Epoch 1: val_loss did not improve from 0.00000
# 3496/3496 - 16s - 5ms/step - loss: 6.2178e-06 - mae: 0.0010 - val_loss: 6.8303e-06 - val_mae: 9.8803e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/34
#
# Epoch 1: val_loss did not improve from 0.00000
# 3549/3549 - 16s - 5ms/step - loss: 6.8585e-06 - mae: 0.0011 - val_loss: 4.7683e-06 - val_mae: 6.8326e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/41
#
# Epoch 1: val_loss did not improve from 0.00000
# 3373/3373 - 15s - 4ms/step - loss: 5.8874e-06 - mae: 0.0010 - val_loss: 8.3348e-06 - val_mae: 0.0011 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/38
#
# Epoch 1: val_loss did not improve from 0.00000
# 3353/3353 - 15s - 4ms/step - loss: 4.7129e-06 - mae: 9.0184e-04 - val_loss: 4.8153e-06 - val_mae: 6.9316e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/43
#
# Epoch 1: val_loss did not improve from 0.00000
# 3513/3513 - 16s - 5ms/step - loss: 6.1095e-06 - mae: 0.0010 - val_loss: 4.7925e-06 - val_mae: 7.0462e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/40
#
# Epoch 1: val_loss did not improve from 0.00000
# 3434/3434 - 16s - 5ms/step - loss: 6.4191e-06 - mae: 0.0010 - val_loss: 5.4566e-06 - val_mae: 6.6877e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/42
#
# Epoch 1: val_loss did not improve from 0.00000
# 3378/3378 - 15s - 5ms/step - loss: 4.6815e-06 - mae: 8.6370e-04 - val_loss: 4.0671e-06 - val_mae: 6.9903e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/45
#
# Epoch 1: val_loss did not improve from 0.00000
# 3327/3327 - 15s - 5ms/step - loss: 4.6359e-06 - mae: 8.8087e-04 - val_loss: 2.5009e-06 - val_mae: 5.5822e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/25
#
# Epoch 1: val_loss did not improve from 0.00000
# 3520/3520 - 16s - 5ms/step - loss: 6.2500e-06 - mae: 0.0010 - val_loss: 4.9599e-06 - val_mae: 7.1710e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/49
#
# Epoch 1: val_loss did not improve from 0.00000
# 3368/3368 - 15s - 5ms/step - loss: 4.6203e-06 - mae: 8.9245e-04 - val_loss: 4.3799e-06 - val_mae: 8.1833e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/48
#
# Epoch 1: val_loss did not improve from 0.00000
# 3504/3504 - 16s - 5ms/step - loss: 6.1225e-06 - mae: 9.7484e-04 - val_loss: 3.6812e-06 - val_mae: 7.0359e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/21
#
# Epoch 1: val_loss did not improve from 0.00000
# 3501/3501 - 16s - 5ms/step - loss: 6.0081e-06 - mae: 0.0011 - val_loss: 1.5068e-05 - val_mae: 0.0013 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/50
#
# Epoch 1: val_loss did not improve from 0.00000
# 3406/3406 - 15s - 5ms/step - loss: 4.8750e-06 - mae: 8.8538e-04 - val_loss: 2.8885e-06 - val_mae: 6.1259e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/32
#
# Epoch 1: val_loss did not improve from 0.00000
# 3592/3592 - 16s - 5ms/step - loss: 6.7779e-06 - mae: 0.0011 - val_loss: 4.6961e-06 - val_mae: 8.5894e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/35
#
# Epoch 1: val_loss did not improve from 0.00000
# 3475/3475 - 16s - 5ms/step - loss: 4.6311e-06 - mae: 9.2349e-04 - val_loss: 9.8447e-06 - val_mae: 9.8514e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/22
#
# Epoch 1: val_loss did not improve from 0.00000
# 3631/3631 - 16s - 5ms/step - loss: 6.5265e-06 - mae: 0.0011 - val_loss: 5.0208e-06 - val_mae: 7.4366e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/44
#
# Epoch 1: val_loss did not improve from 0.00000
# 3505/3505 - 16s - 5ms/step - loss: 6.2142e-06 - mae: 0.0010 - val_loss: 5.7675e-06 - val_mae: 9.5544e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/47
#
# Epoch 1: val_loss did not improve from 0.00000
# 3498/3498 - 16s - 5ms/step - loss: 5.1853e-06 - mae: 8.7731e-04 - val_loss: 3.2051e-06 - val_mae: 6.2366e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/46
#
# Epoch 1: val_loss did not improve from 0.00000
# 3389/3389 - 15s - 5ms/step - loss: 3.8666e-06 - mae: 8.0676e-04 - val_loss: 2.1616e-06 - val_mae: 5.1140e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/59
#
# Epoch 1: val_loss did not improve from 0.00000
# 3377/3377 - 15s - 5ms/step - loss: 3.8504e-06 - mae: 7.5715e-04 - val_loss: 2.2938e-06 - val_mae: 4.8599e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/62
#
# Epoch 1: val_loss did not improve from 0.00000
# 3468/3468 - 16s - 5ms/step - loss: 6.2533e-06 - mae: 0.0010 - val_loss: 4.3880e-06 - val_mae: 6.8287e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/57
#
# Epoch 1: val_loss did not improve from 0.00000
# 3561/3561 - 16s - 5ms/step - loss: 4.7963e-06 - mae: 8.6167e-04 - val_loss: 3.0199e-06 - val_mae: 6.5485e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/55
#
# Epoch 1: val_loss did not improve from 0.00000
# 3481/3481 - 16s - 5ms/step - loss: 5.6711e-06 - mae: 9.5336e-04 - val_loss: 3.2522e-06 - val_mae: 5.6955e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/63
#
# Epoch 1: val_loss did not improve from 0.00000
# 3415/3415 - 15s - 5ms/step - loss: 4.6038e-06 - mae: 8.3899e-04 - val_loss: 3.8374e-06 - val_mae: 7.6591e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/80
#
# Epoch 1: val_loss did not improve from 0.00000
# 3389/3389 - 15s - 5ms/step - loss: 6.6299e-06 - mae: 9.8202e-04 - val_loss: 1.9457e-05 - val_mae: 0.0017 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/52
#
# Epoch 1: val_loss did not improve from 0.00000
# 3410/3410 - 15s - 5ms/step - loss: 5.1619e-06 - mae: 8.9223e-04 - val_loss: 2.8161e-06 - val_mae: 5.3192e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/88
#
# Epoch 1: val_loss did not improve from 0.00000
# 3447/3447 - 16s - 5ms/step - loss: 4.8177e-06 - mae: 9.0585e-04 - val_loss: 3.1434e-06 - val_mae: 7.2958e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/81
#
# Epoch 1: val_loss did not improve from 0.00000
# 3360/3360 - 15s - 5ms/step - loss: 4.4261e-06 - mae: 8.3466e-04 - val_loss: 3.6094e-06 - val_mae: 5.6506e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/54
#
# Epoch 1: val_loss did not improve from 0.00000
# 3362/3362 - 15s - 5ms/step - loss: 4.7204e-06 - mae: 8.8558e-04 - val_loss: 5.6919e-06 - val_mae: 7.4763e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/56
#
# Epoch 1: val_loss did not improve from 0.00000
# 3444/3444 - 16s - 5ms/step - loss: 4.3188e-06 - mae: 8.0775e-04 - val_loss: 2.4924e-06 - val_mae: 5.3010e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/73
#
# Epoch 1: val_loss did not improve from 0.00000
# 3408/3408 - 15s - 5ms/step - loss: 5.1116e-06 - mae: 8.6215e-04 - val_loss: 3.3372e-06 - val_mae: 5.7407e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/51
#
# Epoch 1: val_loss did not improve from 0.00000
# 3451/3451 - 16s - 5ms/step - loss: 5.8779e-06 - mae: 9.7995e-04 - val_loss: 2.7412e-06 - val_mae: 4.8287e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/94
#
# Epoch 1: val_loss did not improve from 0.00000
# 3477/3477 - 16s - 5ms/step - loss: 5.8314e-06 - mae: 9.4810e-04 - val_loss: 4.8306e-06 - val_mae: 7.6245e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/72
#
# Epoch 1: val_loss did not improve from 0.00000
# 3387/3387 - 15s - 5ms/step - loss: 4.6872e-06 - mae: 8.6765e-04 - val_loss: 3.1962e-06 - val_mae: 6.5303e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/58
#
# Epoch 1: val_loss did not improve from 0.00000
# 3436/3436 - 16s - 5ms/step - loss: 4.4317e-06 - mae: 8.2851e-04 - val_loss: 2.5046e-05 - val_mae: 0.0015 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/61
#
# Epoch 1: val_loss did not improve from 0.00000
# 3462/3462 - 16s - 5ms/step - loss: 7.0664e-06 - mae: 0.0010 - val_loss: 5.4239e-06 - val_mae: 7.7286e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/95
#
# Epoch 1: val_loss did not improve from 0.00000
# 3374/3374 - 15s - 5ms/step - loss: 4.8166e-06 - mae: 8.8210e-04 - val_loss: 3.2235e-06 - val_mae: 6.3066e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/78
#
# Epoch 1: val_loss did not improve from 0.00000
# 3262/3262 - 15s - 5ms/step - loss: 4.3014e-06 - mae: 8.7857e-04 - val_loss: 2.3419e-06 - val_mae: 5.3248e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/60
#
# Epoch 1: val_loss did not improve from 0.00000
# 3421/3421 - 16s - 5ms/step - loss: 4.5367e-06 - mae: 8.2642e-04 - val_loss: 7.4672e-06 - val_mae: 8.8258e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/93
#
# Epoch 1: val_loss did not improve from 0.00000
# 3396/3396 - 15s - 5ms/step - loss: 5.3523e-06 - mae: 9.1233e-04 - val_loss: 2.9881e-06 - val_mae: 5.9773e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/67
#
# Epoch 1: val_loss did not improve from 0.00000
# 3440/3440 - 16s - 5ms/step - loss: 5.6197e-06 - mae: 9.4054e-04 - val_loss: 3.8404e-06 - val_mae: 5.8602e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/77
#
# Epoch 1: val_loss did not improve from 0.00000
# 3307/3307 - 15s - 5ms/step - loss: 5.3707e-06 - mae: 9.0215e-04 - val_loss: 4.1999e-06 - val_mae: 7.1720e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/68
#
# Epoch 1: val_loss did not improve from 0.00000
# 3388/3388 - 15s - 5ms/step - loss: 3.9257e-06 - mae: 8.2986e-04 - val_loss: 3.0229e-06 - val_mae: 7.1987e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/65
#
# Epoch 1: val_loss did not improve from 0.00000
# 3444/3444 - 16s - 5ms/step - loss: 6.5490e-06 - mae: 0.0010 - val_loss: 1.3967e-05 - val_mae: 0.0013 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/64
#
# Epoch 1: val_loss did not improve from 0.00000
# 3334/3334 - 15s - 5ms/step - loss: 4.1921e-06 - mae: 8.6610e-04 - val_loss: 3.7259e-06 - val_mae: 6.6324e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/83
#
# Epoch 1: val_loss did not improve from 0.00000
# 3449/3449 - 16s - 5ms/step - loss: 5.4294e-06 - mae: 9.1985e-04 - val_loss: 6.4238e-06 - val_mae: 7.4485e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/66
#
# Epoch 1: val_loss did not improve from 0.00000
# 3391/3391 - 15s - 5ms/step - loss: 4.8477e-06 - mae: 8.8377e-04 - val_loss: 3.0869e-06 - val_mae: 5.5728e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/98
#
# Epoch 1: val_loss did not improve from 0.00000
# 3405/3405 - 15s - 5ms/step - loss: 4.9000e-06 - mae: 8.8331e-04 - val_loss: 2.6819e-06 - val_mae: 5.6510e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/70
#
# Epoch 1: val_loss did not improve from 0.00000
# 3458/3458 - 16s - 5ms/step - loss: 5.6898e-06 - mae: 9.3392e-04 - val_loss: 3.9599e-06 - val_mae: 6.3531e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/89
#
# Epoch 1: val_loss did not improve from 0.00000
# 3354/3354 - 15s - 4ms/step - loss: 4.8065e-06 - mae: 8.3394e-04 - val_loss: 3.9515e-06 - val_mae: 5.5144e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/100
#
# Epoch 1: val_loss did not improve from 0.00000
# 3459/3459 - 16s - 5ms/step - loss: 6.9386e-06 - mae: 0.0010 - val_loss: 4.3488e-06 - val_mae: 7.6678e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/75
#
# Epoch 1: val_loss did not improve from 0.00000
# 3385/3385 - 15s - 5ms/step - loss: 4.6080e-06 - mae: 8.4164e-04 - val_loss: 3.1095e-06 - val_mae: 5.5259e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/91
#
# Epoch 1: val_loss did not improve from 0.00000
# 3542/3542 - 16s - 5ms/step - loss: 6.7655e-06 - mae: 9.9881e-04 - val_loss: 3.9940e-06 - val_mae: 6.7637e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/99
#
# Epoch 1: val_loss did not improve from 0.00000
# 3357/3357 - 15s - 5ms/step - loss: 4.8448e-06 - mae: 8.5260e-04 - val_loss: 5.6326e-06 - val_mae: 8.8750e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/96
#
# Epoch 1: val_loss did not improve from 0.00000
# 3472/3472 - 16s - 5ms/step - loss: 6.4530e-06 - mae: 9.8325e-04 - val_loss: 6.1502e-06 - val_mae: 9.1804e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/53
#
# Epoch 1: val_loss did not improve from 0.00000
# 3466/3466 - 16s - 5ms/step - loss: 5.3922e-06 - mae: 8.8415e-04 - val_loss: 3.5115e-06 - val_mae: 6.1579e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/90
#
# Epoch 1: val_loss did not improve from 0.00000
# 3416/3416 - 16s - 5ms/step - loss: 3.9405e-06 - mae: 8.1773e-04 - val_loss: 2.6387e-06 - val_mae: 5.6715e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/97
#
# Epoch 1: val_loss did not improve from 0.00000
# 3424/3424 - 16s - 5ms/step - loss: 5.6279e-06 - mae: 9.2346e-04 - val_loss: 4.1611e-06 - val_mae: 7.0457e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/74
#
# Epoch 1: val_loss did not improve from 0.00000
# 3371/3371 - 15s - 5ms/step - loss: 5.8906e-06 - mae: 9.5038e-04 - val_loss: 3.7168e-06 - val_mae: 5.7183e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/79
#
# Epoch 1: val_loss did not improve from 0.00000
# 3501/3501 - 16s - 5ms/step - loss: 5.5342e-06 - mae: 9.2506e-04 - val_loss: 7.7447e-06 - val_mae: 8.8339e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/69
#
# Epoch 1: val_loss did not improve from 0.00000
# 3515/3515 - 16s - 5ms/step - loss: 6.4729e-06 - mae: 9.8365e-04 - val_loss: 3.8263e-06 - val_mae: 6.8128e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/82
#
# Epoch 1: val_loss did not improve from 0.00000
# 3508/3508 - 16s - 4ms/step - loss: 5.7954e-06 - mae: 9.3499e-04 - val_loss: 3.3582e-06 - val_mae: 7.1053e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/84
#
# Epoch 1: val_loss did not improve from 0.00000
# 3351/3351 - 15s - 5ms/step - loss: 5.5690e-06 - mae: 9.6173e-04 - val_loss: 4.1341e-06 - val_mae: 7.6486e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/87
#
# Epoch 1: val_loss did not improve from 0.00000
# 3402/3402 - 15s - 5ms/step - loss: 4.8477e-06 - mae: 9.1650e-04 - val_loss: 3.3158e-06 - val_mae: 6.6539e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/85
#
# Epoch 1: val_loss did not improve from 0.00000
# 3536/3536 - 16s - 5ms/step - loss: 6.1215e-06 - mae: 9.9606e-04 - val_loss: 4.8508e-06 - val_mae: 7.9598e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/71
#
# Epoch 1: val_loss did not improve from 0.00000
# 3428/3428 - 15s - 5ms/step - loss: 5.0650e-06 - mae: 9.2785e-04 - val_loss: 2.8581e-06 - val_mae: 5.6581e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/76
#
# Epoch 1: val_loss did not improve from 0.00000
# 3491/3491 - 16s - 5ms/step - loss: 4.7219e-06 - mae: 8.4966e-04 - val_loss: 3.2307e-06 - val_mae: 5.9443e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/86
#
# Epoch 1: val_loss did not improve from 0.00000
# 3377/3377 - 15s - 5ms/step - loss: 4.6613e-06 - mae: 8.7737e-04 - val_loss: 3.3859e-06 - val_mae: 6.1196e-04 - learning_rate: 1.0000e-03
# Processing: snapshots/strategy2/92
#
# Epoch 1: val_loss did not improve from 0.00000
# 3386/3386 - 15s - 5ms/step - loss: 5.0212e-06 - mae: 8.8428e-04 - val_loss: 6.3179e-06 - val_mae: 8.4332e-04 - learning_rate: 1.0000e-03

# %%
import random
sample = random.randint(1000, 3000000)
#sample = 94
print(f"Chosen sample: {sample}")
counter = -1
with open("sudoku_extreme_dataset/train.csv") as fh:
    for line in fh:
        if counter == sample:
            question = line.split(",")[1]
            grid = np.array(get_sudoku_grid(question))
            snapshots_dir = f"snapshots/{sample}"
            break
        counter += 1
    else:
        raise Exception("Invalid sample number")
load_model_and_solve('sudoku_mlp_2_layers_swish.keras', grid, save_image='sudoku_solution_nn.png')
# Out:
# Chosen sample: 1153086
# Accuracy: 81.48148148148148
